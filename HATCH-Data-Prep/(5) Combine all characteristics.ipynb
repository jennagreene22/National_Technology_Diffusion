# %%
#good 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import os.path
import seaborn as sns

from matplotlib.pyplot import cm

warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore')
pd.options.mode.chained_assignment = None
from scipy.optimize import curve_fit

# %%
#os.chdir('/Users/jennagreene/Library/Mobile Documents/com~apple~CloudDocs/Documents/GitHub/country-tech-growth')
os.chdir('/Users/jennagreene/Documents/GitHub/country-tech-growth')

# %%
country_vars = pd.read_csv("all_gov_combined_Updated.csv", index_col = False)


tech_vars = pd.read_csv("combined_tech_characteristics_Updated.csv", index_col = False)
timeseries = pd.read_csv('all_tech_clean_cumulative_Updated.csv', index_col = False)




tech_vars
country_vars
# Out:
#                                  Variable       technology country  \
# 0       Sugar Output_Annual Production_JM     Sugar Output     JAM
# 1       Sugar Output_Annual Production_BB     Sugar Output     BRB
# 2       Sugar Output_Annual Production_CU     Sugar Output     CUB
# 3               Beer_Annual Production_GB  Beer Production     GBR
# 4       Sugar Output_Annual Production_MU     Sugar Output     MUS
# ...                                   ...              ...     ...
# 6027       Crop Harvester_Total Number_UZ   Crop Harvester     UZB
# 6028           Television_Total Number_BA       Television     BIH
# 6029   BCG Vaccine_Share of Population_AT      BCG Vaccine     AUT
# 6030  MCV2 Vaccine_Share of Population_DJ     MCV2 Vaccine     DJI
# 6031       Crop Harvester_Total Number_UA   Crop Harvester     UKR
#
#             Country Name               Metric        Exponential Fit  \
# 0                Jamaica    Annual Production   0.010363684595067636
# ...

# %%
tech_vars['technology'].unique()
# Out:
# array(['Acrylic Fiber', 'Acrylonitrile', 'Air-Source Heat Pumps',
#        'All Biofuels', 'Amazon Prime Users', 'Ammonia Synthesis',
#        'Aniline', 'Aquaculture Production', 'Automatic Transmission',
#        'BCG Vaccine', 'Beer Production', 'Benzene', 'Bicycles', 'Biogas',
#        'BisphenolA', 'Cable TV', 'Cadmium Refining', 'Canals',
#        'Cane Sugar', 'Caprolactam', 'Capture Fisheries',
#        'Carbon Capture and Sequestration', 'Caustic Soda', 'Cellphones',
#        'Cement', 'Central Heating', 'Coal Power', 'Coal Production',
#        'Cobalt', 'Compact Fluorescent Light Bulbs', 'Computing Growth',
#        'Copper|Mining', 'Copper|Refining', 'Crop Harvester', 'Crude Oil',
#        'Cyclohexane', 'Desalination Capacity', 'Dishwashers',
#        'Disk Brakes', 'DTP1 Vaccine', 'DTP3 Vaccine', 'Ebook Reader',
#        'Electric Bicycles', 'Electric Range', 'Electricity',
#        'Electronic Ignition', 'Ethanol', 'Ethanolamine', 'Ethylene',
# ...

# %%
all_growth_merge = pd.merge(country_vars, tech_vars, on='technology', how='inner')

all_growth_merge.columns
# Out:
# Index(['Variable', 'technology', 'country', 'Country Name', 'Metric',
#        'Exponential Fit', 'exponential goodness', 'Logistic Fit',
#        'Logistic Saturation', 'Logistic Inflection Year', 'logistic goodness',
#        'Gompertz Fit', 'gompertz goodness', 'Delta T', 'Vintage',
#        'Number of Points', 'lendingrate_Average', 'rdspending_Average',
#        'goodsservices_Average', 'oresmetals_Average', 'fdi_Average',
#        'hightech_Average', 'polity_Average', 'direction_scitech_Average',
#        'easier_scitech_Average', 'gdppc_Average', 'Capacity_Average',
#        'gee_Average', 'regime_Mode', 'IncomeGroup_Mode', 'WTO_Mode',
#        'OECD_Mode', 'dem', 'Log_GDPavg', 'Material Use Numerical',
#        'Final Material Use', 'Year of Invention',
#        'Year of First Embodiment of Tech', 'FirstCommercialYr',
#        'Need for Customization', 'Complexity', 'Type of Adopter',
#        'Granularity Numerical', 'Granularity', 'Average lifetime',
# ...

# %%
all_growth_merge = all_growth_merge.rename(columns={'Variable': 'ID'})

# %%
all_growth_merge
# Out:
#                                  Variable       technology country  \
# 0               Beer_Annual Production_GB  Beer Production     GBR
# 1                Railroad_Total Length_FI         Railroad     FIN
# 2                Railroad_Total Length_FR         Railroad     FRA
# 3                Railroad_Total Length_NO         Railroad     NOR
# 4                Railroad_Total Length_DK         Railroad     DNK
# ...                                   ...              ...     ...
# 5594       Crop Harvester_Total Number_UZ   Crop Harvester     UZB
# 5595           Television_Total Number_BA       Television     BIH
# 5596   BCG Vaccine_Share of Population_AT      BCG Vaccine     AUT
# 5597  MCV2 Vaccine_Share of Population_DJ     MCV2 Vaccine     DJI
# 5598       Crop Harvester_Total Number_UA   Crop Harvester     UKR
#
#             Country Name               Metric        Exponential Fit  \
# 0                     UK    Annual Production                    err
# ...

# %%
# Count number of points. 
# all_growth_merge has the characteristics
# Original growth is in time_series
characteristics_timeseries_merge =all_growth_merge.merge( timeseries, on='ID', how='inner')

# %%
characteristics_timeseries_merge_sum
# Out:
#       1702  1703  1704  1705  1706  1707  1708  1709  1710  1711  ...  2016  \
# 0      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 1      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 2      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 3      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 4      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 5594   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 5595   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 5596   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 5597   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  0.81
# 5598   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
#
# ...

# %%
characteristics_timeseries_merge
characteristics_timeseries_merge_sum = characteristics_timeseries_merge.iloc[:,60:]
# Count the number of non-zero and non-NaN values in the entire DataFrame
non_zero_non_nan_counts = ((characteristics_timeseries_merge_sum != 0) & (~characteristics_timeseries_merge_sum.isna())).sum().sum()

# Print the result
print("Total non-zero and non-NaN values in the DataFrame:", non_zero_non_nan_counts)
# Out:
# Total non-zero and non-NaN values in the DataFrame: 204784

# %%
all_growth_merge.to_csv('all_growth_merge_Updated.csv', index = False)

# %%
# Define the new folder path
new_folder = "summary_tables"

# Change the current working directory to the new folder
os.chdir(new_folder)


tech_char = pd.read_csv("sorted_tech_characteristics_Updated.csv", index_col = False)
tech_char = tech_char.rename(columns={"Technology Name": "technology", "Country Name": "country"})
tech_char
# Out:
#       Unnamed: 0             technology country  num values  num years  \
# 0           5675  Air-Source Heat Pumps     NOR          13         13
# 1           5545  Air-Source Heat Pumps     POL          14         14
# 2           5744  Air-Source Heat Pumps     CZE          12         12
# 3           5028  Air-Source Heat Pumps     USA          20         20
# 4           5661  Air-Source Heat Pumps     CHE          13         13
# ...          ...                    ...     ...         ...        ...
# 6027        1060                   Zinc     ARG          62         62
# 6028         340                   Zinc     AUS         109        109
# 6029        2968                   Zinc     IND          37         37
# 6030        3616                   Zinc     DZA          30         30
# 6031         667                   Zinc     PER          64         64
#
#       First Year of Data  First Value  Last Year of Data  Last Value
# ...
