# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import os.path
from countrycode import countrycode

from matplotlib.pyplot import cm

warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore')
pd.options.mode.chained_assignment = None

# %%
# Read in CSVs

new_directory = '/Users/jennagreene/Documents/GitHub/country-tech-growth/Tech_Characteristics' 
os.chdir(new_directory)

all_files = os.listdir(new_directory)

all_files
# Out:
# ['MaterialUse.csv',
#  '.DS_Store',
#  'Tech_FirstYrCommercial.csv',
#  'All_Technology_Characteristics.csv',
#  'Granularity.csv',
#  'TechReplacement.csv',
#  'TechLifetime.csv',
#  'Feed.csv',
#  'Technology Categories.csv']

# %%
# Cycle through csv files in the directory

dfs = [pd.read_csv(os.path.join(new_directory, file)) for file in all_files if file.endswith('.csv')]

# %%
common_technologies = set(dfs[0]['Technology'])
for df in dfs[1:]:
    common_technologies = common_technologies.intersection(set(df['Technology']))

print(common_technologies   )
print(len(common_technologies))
# Out:
# {'Cyclohexane', 'High Speed Rail', 'Synthetic Filaments', 'Amazon Prime Users', 'Air-Source Heat Pumps', 'Nitrogen Fertilizer', 'Nuclear Weapons', 'Lead-Acid Battery Storage', 'BCG Vaccine', 'Laundry Dryers', 'Tin', 'Crop Harvester', 'Jet Aircraft', 'Microprocessor Clock Speed', 'Liquefied Natural Gas', 'Computing Growth', 'Sulphuric Acid', 'Sodium-Based Battery Storage', 'Natural Gas Power', 'Sodium Chlorate', 'Vinyl Acetate', 'Microcomputers', 'Aquaculture Production', 'Caprolactam', 'Titanium Sponge', 'Crude Oil', 'Pentaerythritol', 'Postal Traffic', 'All Biofuels', 'Herbicide-Tolerant Corn', 'Carbon Capture and Sequestration', 'Lead', 'Solid Biofuels', 'Random Access Memory', 'Acrylic Fiber', 'Coal Production', 'Motorcycles', 'Renewable Power', 'Microwaves', 'Paraxylene', 'Shotgun Sanger DNA Sequencing', 'Sand and Gravel|Construction', 'Marine Energy', 'Insect-Resistant Cotton', 'Vinyl Chloride', 'Beer Production', 'Primary Bauxite Production', 'Ethanol', 'Primary Magnesium', 'Electric Bicycles', 'Washing Machines', 'Tablet', 'Liquid Biofuels', 'Sand and Gravel|Industrial', 'Oil Refining Capacity', 'DTP1 Vaccine', 'Iron Ore', 'MCV2 Vaccine', 'Solar Photovoltaic', 'Phosphate Fertilizer', 'Gold', 'Nickel Production', 'Herbicide-Tolerant Soybeans', 'Hydroelectricity', 'Insect-Resistant Corn', 'Iron', 'Methanol', 'POL3 Vaccine', 'Caustic Soda', 'Hydrofluoric Acid', 'Flywheel Battery Storage', 'Low-Density Polyethylene', 'Ethylene Glycol', 'Running Water', 'Power Steering', 'Onshore Wind Energy', 'Zinc', 'Phthalic Anhydride', 'Urea', 'Geothermal Energy', 'Lithium-Ion Battery Storage', 'Ebook Reader', 'Nuclear Energy', 'Transistors per Microprocessor', 'Natural Gas Pipelines', 'Maleic Anhydride', 'Central Heating', 'Copper|Mining', 'MCV1 Vaccine', 'DTP3 Vaccine', 'Polyester Fiber', 'Households With Only Mobile Phones (No Landlines)', 'Sensible Heat Storage', 'Styrene', 'YFV Vaccine', 'Phenol', 'High-Density Polyethylene', 'Oil Production', 'Hydrochloric Acid', 'Cellphones', 'Submarine Cables', 'HEPB3 Vaccine', 'Coal Power', 'Videocassette Recorder', 'Pumped Hydro Storage', 'Oil Pipelines', 'Sodium', 'Benzene', 'HIB3 Vaccine', 'Steamships', 'Silver', 'Internet Backbone Bandwidth', 'Cement', 'Magnetic Data Storage', 'Compact Fluorescent Light Bulbs', 'Heat Thermal Battery Storage', 'Primary Aluminum Production', 'Salt Production', 'Capture Fisheries', 'Social Media Usage', 'Natural Gas Production', 'Formaldehyde', 'Cable TV', 'Electronic Ignition', 'RCV1 Vaccine', 'Bicycles', 'Cobalt', 'Potash Fertilizer', 'Neoprene Rubber', 'Rare Earth Mine Production', 'Podcasting', 'Nitric Acid', 'Refrigerators', 'BisphenolA', 'Dishwashers', 'Lithium Mine Production', 'Canals', 'Electric Range', 'Solar Thermal Energy', 'Objects Launched Into Space', 'Automatic Transmission', 'Nox Pollution Controls (Boilers)', 'Motor Gasoline', 'Radio', 'Household Internet Access', 'IPV1 Vaccine', 'Aniline', 'PCV3 Vaccine', 'Stove', 'Polystyrene', 'Television', 'Herbicide-Tolerant Cotton', 'Milk Production', 'Freezer', 'Latent Heat Storage', 'Primary Copper', 'Cadmium Refining', 'Radial Tires', 'ROTAC Vaccine', 'Real-Time Gross Settlement Adoption', 'Copper|Refining', 'Graphite', 'Processor Performance', 'Ethanolamine', 'Cane Sugar', 'Public Roads', 'Flush Toilet', 'Polyvinylchloride', 'Telephones', 'Raw Steel Production', 'Water Heater', 'Biogas', 'Acrylonitrile', 'Railroad', 'Ammonia Synthesis', 'Flow Battery Storage', 'Telegraph Traffic', 'Wet Flue Gas Desulfurization Systems', 'Internet Traffic', 'Offshore Wind Energy', 'Vacuums', 'Ethylene', 'HEPBB Vaccine', 'Home Computers', 'Desalination Capacity', 'Home Air Conditioning', 'Smartphone Usage', 'Disk Brakes', 'Shale Production', 'Electricity', 'Fluid Catalytic Cracking Refineries'}
# 191

# %%
# Step 3: Create a new dataframe containing only rows with common technologies
combined_data = dfs[0]
for df in dfs[1:]:
    combined_data = pd.merge(combined_data, 
                             df[df['Technology'].isin(common_technologies)], 
                             on='Technology', 
                             how='inner')


combined_data['Technology'].unique()
# Out:
# array(['Acrylic Fiber', 'Acrylonitrile', 'Air-Source Heat Pumps',
#        'All Biofuels', 'Amazon Prime Users', 'Ammonia Synthesis',
#        'Aniline', 'Aquaculture Production', 'Automatic Transmission',
#        'BCG Vaccine', 'Beer Production', 'Benzene', 'Bicycles', 'Biogas',
#        'BisphenolA', 'Cable TV', 'Cadmium Refining', 'Canals',
#        'Cane Sugar', 'Caprolactam', 'Capture Fisheries',
#        'Carbon Capture and Sequestration', 'Caustic Soda', 'Cellphones',
#        'Cement', 'Central Heating', 'Coal Power', 'Coal Production',
#        'Cobalt', 'Compact Fluorescent Light Bulbs', 'Computing Growth',
#        'Copper|Mining', 'Copper|Refining', 'Crop Harvester', 'Crude Oil',
#        'Cyclohexane', 'Desalination Capacity', 'Dishwashers',
#        'Disk Brakes', 'DTP1 Vaccine', 'DTP3 Vaccine', 'Ebook Reader',
#        'Electric Bicycles', 'Electric Range', 'Electricity',
#        'Electronic Ignition', 'Ethanol', 'Ethanolamine', 'Ethylene',
#        'Ethylene Glycol', 'Flow Battery Storage',
#        'Fluid Catalytic Cracking Refineries', 'Flush Toilet',
#        'Flywheel Battery Storage', 'Formaldehyde', 'Freezer',
#        'Geothermal Energy', 'Gold', 'Graphite',
#        'Heat Thermal Battery Storage', 'HEPB3 Vaccine', 'HEPBB Vaccine',
#        'Herbicide-Tolerant Corn', 'Herbicide-Tolerant Cotton',
#        'Herbicide-Tolerant Soybeans', 'HIB3 Vaccine',
#        'High-Density Polyethylene', 'High Speed Rail',
#        'Home Air Conditioning', 'Home Computers',
#        'Household Internet Access',
#        'Households With Only Mobile Phones (No Landlines)',
#        'Hydrochloric Acid', 'Hydroelectricity', 'Hydrofluoric Acid',
#        'Insect-Resistant Corn', 'Insect-Resistant Cotton',
#        'Internet Backbone Bandwidth', 'Internet Traffic', 'IPV1 Vaccine',
#        'Iron', 'Iron Ore', 'Jet Aircraft', 'Latent Heat Storage',
#        'Laundry Dryers', 'Lead', 'Lead-Acid Battery Storage',
#        'Liquefied Natural Gas', 'Liquid Biofuels',
#        'Lithium Mine Production', 'Lithium-Ion Battery Storage',
#        'Low-Density Polyethylene', 'Magnetic Data Storage',
#        'Maleic Anhydride', 'Marine Energy', 'MCV1 Vaccine',
#        'MCV2 Vaccine', 'Methanol', 'Microcomputers',
#        'Microprocessor Clock Speed', 'Microwaves', 'Milk Production',
#        'Motor Gasoline', 'Motorcycles', 'Natural Gas Pipelines',
#        'Natural Gas Power', 'Natural Gas Production', 'Neoprene Rubber',
#        'Nickel Production', 'Nitric Acid', 'Nitrogen Fertilizer',
#        'Nox Pollution Controls (Boilers)', 'Nuclear Energy',
#        'Nuclear Weapons', 'Offshore Wind Energy', 'Oil Pipelines',
#        'Oil Production', 'Oil Refining Capacity', 'Onshore Wind Energy',
#        'Paraxylene', 'PCV3 Vaccine', 'Pentaerythritol', 'Phenol',
#        'Phosphate Fertilizer', 'Phthalic Anhydride', 'Podcasting',
#        'POL3 Vaccine', 'Polyester Fiber', 'Polystyrene',
#        'Polyvinylchloride', 'Postal Traffic', 'Potash Fertilizer',
#        'Power Steering', 'Primary Aluminum Production',
#        'Primary Bauxite Production', 'Primary Copper',
#        'Primary Magnesium', 'Processor Performance', 'Public Roads',
#        'Pumped Hydro Storage', 'Radial Tires', 'Radio', 'Railroad',
#        'Random Access Memory', 'Rare Earth Mine Production',
#        'Raw Steel Production', 'RCV1 Vaccine',
#        'Real-Time Gross Settlement Adoption', 'Refrigerators',
#        'Renewable Power', 'ROTAC Vaccine', 'Running Water',
#        'Salt Production', 'Sand and Gravel|Construction',
#        'Sand and Gravel|Industrial', 'Sensible Heat Storage',
#        'Shale Production', 'Shotgun Sanger DNA Sequencing', 'Silver',
#        'Smartphone Usage', 'Social Media Usage', 'Sodium',
#        'Sodium Chlorate', 'Sodium-Based Battery Storage',
#        'Solar Photovoltaic', 'Solar Thermal Energy', 'Solid Biofuels',
#        'Objects Launched Into Space', 'Steamships', 'Stove', 'Styrene',
#        'Submarine Cables', 'Sulphuric Acid', 'Synthetic Filaments',
#        'Tablet', 'Telegraph Traffic', 'Telephones', 'Television', 'Tin',
#        'Titanium Sponge', 'Transistors per Microprocessor', 'Urea',
#        'Vacuums', 'Videocassette Recorder', 'Vinyl Acetate',
#        'Vinyl Chloride', 'Washing Machines', 'Water Heater',
#        'Wet Flue Gas Desulfurization Systems', 'YFV Vaccine', 'Zinc'],
#       dtype=object)

# %% [markdown]
# In this step, we keep only certain columns (categorization of technologies and numerical for those with those columns)

# %%
charac_of_interest = ['Technology',
                      'Kg per dollar',
                      'Final Material Use',
                      'Year of Invention',
                      'Year of First Embodiment of Tech',
                      'Year of First Commercialization',
                      'Need for Customization',
                      'Complexity',
                      'Type of Adopter',
                      'Unit Price / Investment Size at t0 (09 dollars)',
                      'Granularity Category', 
                      'Average lifetime (years)',
                      'Technology Lifetime (Final)',
                      'Strict replacement', 
                      'Broad Replacement?', 
                      'Requires a Feedstock?', 
                      'Other Category Type', 
                      'Patent Category Name']
combined_data = combined_data[charac_of_interest]

combined_data
# Out:
#                                Technology  Kg per dollar   Final Material Use  \
# 0                           Acrylic Fiber       1.321877    High Material Use
# 1                           Acrylonitrile       0.793651  Medium Material Use
# 2                   Air-Source Heat Pumps       0.014898  Medium Material Use
# 3                            All Biofuels            NaN  Medium Material Use
# 4                      Amazon Prime Users            NaN                  NaN
# ..                                    ...            ...                  ...
# 193                      Washing Machines       0.179997  Medium Material Use
# 194                          Water Heater       0.047249     Low Material Use
# 195  Wet Flue Gas Desulfurization Systems       0.000000  Medium Material Use
# 196                           YFV Vaccine       0.000042     Low Material Use
# 197                                  Zinc       0.478927  Medium Material Use
#
#     Year of Invention Year of First Embodiment of Tech  \
# 0                1948                              NaN
# 1                1893                              NaN
# 2                 NaN                              NaN
# 3                 n/d                              NaN
# 4                 NaN                              NaN
# ..                ...                              ...
# 193              1875                              NaN
# 194              1868                             1889
# 195               NaN                              NaN
# 196               NaN                              NaN
# 197               NaN                              NaN
#
#     Year of First Commercialization Need for Customization  \
# 0                              1950    Mass-customized [2]
# 1                              1930    Mass-customized [2]
# 2                              1938       Standardized [1]
# 3                               n/d    Mass-Customized [2]
# 4                              2005       Standardized [1]
# ..                              ...                    ...
# 193                            1908       Standardized [1]
# 194                            1906       Standardized [1]
# 195                            1931    Mass-customized [2]
# 196                            1937       Standardized [1]
# 197                            1743         Customized [3]
#
#                Complexity  Type of Adopter  \
# 0             Complex [3]        Firms [1]
# 1             Complex [3]        Firms [1]
# 2              Simple [1]  Individuals [2]
# 3             Complex [3]        Firms [1]
# 4    Design-Intensive [2]  Individuals [2]
# ..                    ...              ...
# 193            Simple [1]  Individuals [2]
# 194            Simple [1]  Individuals [2]
# 195  Design-Intensive [2]        Firms [1]
# 196            Simple [1]  Individuals [2]
# 197           Complex [3]        Firms [1]
#
#     Unit Price / Investment Size at t0 (09 dollars) Granularity Category  \
# 0                                          43000000                  Low
# 1                                          15050000                  Low
# 2                                              9800               Medium
# 3                                               NaN                  Low
# 4                                               139                 High
# ..                                              ...                  ...
# 193                                     1766.488794               Medium
# 194                                             NaN               Medium
# 195                                      2253160800                  Low
# 196                                            16.7                 High
# 197                                       Expensive                  Low
#
#      Average lifetime (years) Technology Lifetime (Final) Strict replacement  \
# 0                         NaN                     Decades                Yes
# 1                        30.0                     Decades                 No
# 2                        15.0                       Years                Yes
# 3                         3.0                       Years                 No
# 4                         NaN                         NaN                Yes
# ..                        ...                         ...                ...
# 193                      12.0                       Years                Yes
# 194                       9.0                       Years                 No
# 195                       NaN                     Decades                 No
# 196                       3.0                       Years                 No
# 197                       NaN                     Decades                 No
#
#     Broad Replacement? Requires a Feedstock?       Other Category Type  \
# 0                  Yes                   NaN  Chemicals and Industrial
# 1                  Yes                   NaN  Chemicals and Industrial
# 2                  Yes                   NaN                Appliances
# 3                   No                   Yes             Energy Supply
# 4                  Yes                   NaN            Digitalization
# ..                 ...                   ...                       ...
# 193                Yes                   NaN                Appliances
# 194                Yes                   NaN                Appliances
# 195                 No                    No             Energy Supply
# 196                 No                    No           Food and Health
# 197                 No                    No                 Materials
#
#                                   Patent Category Name
# 0                                      Textiles; Paper
# 1                                Chemistry; Metallurgy
# 2    Mechanical Engineering; Lighting; Heating; Wea...
# 3    General Tagging of New Technological Developme...
# 4                                              Physics
# ..                                                 ...
# 193                                    Textiles; Paper
# 194                                  Human Necessities
# 195  General Tagging of New Technological Developme...
# 196                                  Human Necessities
# 197                                Fixed Constructions
#
# [198 rows x 18 columns]

# %%
# Rename columns
new_names = ['technology',
             'Material Use Numerical',
            'Final Material Use',
            'Year of Invention',
            'Year of First Embodiment of Tech',
            'FirstCommercialYr',
            'Need for Customization',
            'Complexity',
            'Type of Adopter',
            'Granularity Numerical',
            'Granularity', 
            'Average lifetime',
            'Technology Lifetime',
            'Strict replacement', 
            'Broad replacement', 
            'Feedstock', 
            'Category Type', 
            'Patent Category Name']


combined_data.columns = new_names

combined_data


new_directory = '/Users/jennagreene/Documents/GitHub/country-tech-growth/' 
os.chdir(new_directory)

combined_data.to_csv('combined_tech_characteristics_Updated.csv', index=False)
