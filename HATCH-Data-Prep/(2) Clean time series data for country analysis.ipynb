# %% [markdown]
# # Clean dataframe from HATCH Version 1.5
# ## Country Level Data
#
# First Run: "(1) Clean HATCH Dataset - IIAC And Other Uses" jupyter notebook
#
# #### This notebook changes country names for alignment
# - Checks data cleanliness
# - Converts country names to ISO3c codes
# - annual to cumulative values

# %%
# Import packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import os.path
from countrycode import countrycode

from matplotlib.pyplot import cm

warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore')
pd.options.mode.chained_assignment = None

# %% [markdown]
# #### Import data

# %%
#Import data from cleaned CSV

path_name = "clean_HATCHv1.5_internal.csv"
all_tech_country = pd.read_csv(path_name, low_memory = False)

# Drop "Unnamed:0" if it exists.
try: 
    all_tech_country = all_tech_country.drop('Unnamed: 0', axis=1)
except:
    print("Columns are consistent.")

all_tech_country
# Out:
# Columns are consistent.
#                                        ID Spatial Scale Region  \
# 0       Sugar Output_Annual Production_JM      National     JM
# 1       Sugar Output_Annual Production_BB      National     BB
# 2       Sugar Output_Annual Production_CU      National     CU
# 3               Beer_Annual Production_GB      National     GB
# 4       Sugar Output_Annual Production_MU      National     MU
# ...                                   ...           ...    ...
# 6132       Crop Harvester_Total Number_UZ      National     UZ
# 6133           Television_Total Number_BA      National     BA
# 6134   BCG Vaccine_Share of Population_AT      National     AT
# 6135  MCV2 Vaccine_Share of Population_DJ      National     DJ
# 6136       Crop Harvester_Total Number_UA      National     UA
#
#             Country Name  Technology Name               Metric  \
# 0                Jamaica     Sugar Output    Annual Production
# 1               Barbados     Sugar Output    Annual Production
# 2                   Cuba     Sugar Output    Annual Production
# 3                     UK  Beer Production    Annual Production
# 4              Mauritius     Sugar Output    Annual Production
# ...                  ...              ...                  ...
# 6132          Uzbekistan   Crop Harvester         Total Number
# 6133  Bosnia-Herzegovina       Television         Total Number
# 6134             Austria      BCG Vaccine  Share of Population
# 6135            Djibouti     MCV2 Vaccine  Share of Population
# 6136             Ukraine   Crop Harvester         Total Number
#
#                       Unit Data Source  \
# 0     thousand metric tons    Mitchell
# 1     thousand metric tons    Mitchell
# 2     thousand metric tons    Mitchell
# 3     thousand hectolitres    Mitchell
# 4     thousand metric tons    Mitchell
# ...                    ...         ...
# 6132                     -        CHAT
# 6133                     -        CHAT
# 6134                     %      UNICEF
# 6135                     %      UNICEF
# 6136                     -        CHAT
#
#                                              Variable  1700  ...  2016  2017  \
# 0                        Annual Production|Cane Sugar   NaN  ...   NaN   NaN
# 1                        Annual Production|Cane Sugar   NaN  ...   NaN   NaN
# 2                        Annual Production|Cane Sugar   NaN  ...   NaN   NaN
# 3                              Annual Production|Beer   NaN  ...   NaN   NaN
# 4                        Annual Production|Cane Sugar   NaN  ...   NaN   NaN
# ...                                               ...   ...  ...   ...   ...
# 6132                   Number of Units|Crop Harvester   NaN  ...   NaN   NaN
# 6133                      Number of Units|Televisions   NaN  ...   NaN   NaN
# 6134         Share of Population|Tuberculosis Vaccine   NaN  ...   NaN   NaN
# 6135  Share of Population|Measles Vaccine Second Dose   NaN  ...  0.81  0.81
# 6136                   Number of Units|Crop Harvester   NaN  ...   NaN   NaN
#
#       2018  2019  2020  2021  2022  2023  2024  2025
# 0      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...    ...   ...   ...   ...   ...   ...   ...   ...
# 6132   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6133   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6134   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6135  0.81  0.81   0.6  0.48   NaN   NaN   NaN   NaN
# 6136   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [6137 rows x 335 columns]

# %% [markdown]
# ### Drop Non-Relevant Metrics
#
# Costs, cumulative rated capacity (duplicates from storage technologies), and any typos

# %%
# Drop non-relevant metrics (cost, duplicate measures for storage)
all_tech_country.drop(all_tech_country[all_tech_country['Metric'] == "Cumulative Rated Capacity"].index, inplace = True)

all_tech_country = all_tech_country[~all_tech_country['Metric'].str.contains('Cost')]

all_tech_country
# Out:
#                                        ID Spatial Scale Region  \
# 0       Sugar Output_Annual Production_JM      National     JM
# 1       Sugar Output_Annual Production_BB      National     BB
# 2       Sugar Output_Annual Production_CU      National     CU
# 3               Beer_Annual Production_GB      National     GB
# 4       Sugar Output_Annual Production_MU      National     MU
# ...                                   ...           ...    ...
# 6132       Crop Harvester_Total Number_UZ      National     UZ
# 6133           Television_Total Number_BA      National     BA
# 6134   BCG Vaccine_Share of Population_AT      National     AT
# 6135  MCV2 Vaccine_Share of Population_DJ      National     DJ
# 6136       Crop Harvester_Total Number_UA      National     UA
#
#             Country Name  Technology Name               Metric  \
# 0                Jamaica     Sugar Output    Annual Production
# 1               Barbados     Sugar Output    Annual Production
# 2                   Cuba     Sugar Output    Annual Production
# 3                     UK  Beer Production    Annual Production
# 4              Mauritius     Sugar Output    Annual Production
# ...                  ...              ...                  ...
# 6132          Uzbekistan   Crop Harvester         Total Number
# 6133  Bosnia-Herzegovina       Television         Total Number
# 6134             Austria      BCG Vaccine  Share of Population
# 6135            Djibouti     MCV2 Vaccine  Share of Population
# 6136             Ukraine   Crop Harvester         Total Number
#
#                       Unit Data Source  \
# 0     thousand metric tons    Mitchell
# 1     thousand metric tons    Mitchell
# 2     thousand metric tons    Mitchell
# 3     thousand hectolitres    Mitchell
# 4     thousand metric tons    Mitchell
# ...                    ...         ...
# 6132                     -        CHAT
# 6133                     -        CHAT
# 6134                     %      UNICEF
# 6135                     %      UNICEF
# 6136                     -        CHAT
#
#                                              Variable  1700  ...  2016  2017  \
# 0                        Annual Production|Cane Sugar   NaN  ...   NaN   NaN
# 1                        Annual Production|Cane Sugar   NaN  ...   NaN   NaN
# 2                        Annual Production|Cane Sugar   NaN  ...   NaN   NaN
# 3                              Annual Production|Beer   NaN  ...   NaN   NaN
# 4                        Annual Production|Cane Sugar   NaN  ...   NaN   NaN
# ...                                               ...   ...  ...   ...   ...
# 6132                   Number of Units|Crop Harvester   NaN  ...   NaN   NaN
# 6133                      Number of Units|Televisions   NaN  ...   NaN   NaN
# 6134         Share of Population|Tuberculosis Vaccine   NaN  ...   NaN   NaN
# 6135  Share of Population|Measles Vaccine Second Dose   NaN  ...  0.81  0.81
# 6136                   Number of Units|Crop Harvester   NaN  ...   NaN   NaN
#
#       2018  2019  2020  2021  2022  2023  2024  2025
# 0      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...    ...   ...   ...   ...   ...   ...   ...   ...
# 6132   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6133   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6134   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6135  0.81  0.81   0.6  0.48   NaN   NaN   NaN   NaN
# 6136   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [6127 rows x 335 columns]

# %%
# Drop duplicate - air conditioners in the US
all_tech_country.drop(all_tech_country[
    (all_tech_country['Country Name'] == "United States") & 
    (all_tech_country['Technology Name'] == "Home Air Conditioning") & 
    (all_tech_country['Metric'] == 'Share of Households')
].index, inplace=True)

# %% [markdown]
# #### Create dataframe of only the descriptors

# %%
tech_timeseries_sum = all_tech_country.iloc[:, :9]
tech_timeseries_sum
# Out:
#                                        ID Spatial Scale Region  \
# 0       Sugar Output_Annual Production_JM      National     JM
# 1       Sugar Output_Annual Production_BB      National     BB
# 2       Sugar Output_Annual Production_CU      National     CU
# 3               Beer_Annual Production_GB      National     GB
# 4       Sugar Output_Annual Production_MU      National     MU
# ...                                   ...           ...    ...
# 6132       Crop Harvester_Total Number_UZ      National     UZ
# 6133           Television_Total Number_BA      National     BA
# 6134   BCG Vaccine_Share of Population_AT      National     AT
# 6135  MCV2 Vaccine_Share of Population_DJ      National     DJ
# 6136       Crop Harvester_Total Number_UA      National     UA
#
#             Country Name  Technology Name               Metric  \
# 0                Jamaica     Sugar Output    Annual Production
# 1               Barbados     Sugar Output    Annual Production
# 2                   Cuba     Sugar Output    Annual Production
# 3                     UK  Beer Production    Annual Production
# 4              Mauritius     Sugar Output    Annual Production
# ...                  ...              ...                  ...
# 6132          Uzbekistan   Crop Harvester         Total Number
# 6133  Bosnia-Herzegovina       Television         Total Number
# 6134             Austria      BCG Vaccine  Share of Population
# 6135            Djibouti     MCV2 Vaccine  Share of Population
# 6136             Ukraine   Crop Harvester         Total Number
#
#                       Unit Data Source  \
# 0     thousand metric tons    Mitchell
# 1     thousand metric tons    Mitchell
# 2     thousand metric tons    Mitchell
# 3     thousand hectolitres    Mitchell
# 4     thousand metric tons    Mitchell
# ...                    ...         ...
# 6132                     -        CHAT
# 6133                     -        CHAT
# 6134                     %      UNICEF
# 6135                     %      UNICEF
# 6136                     -        CHAT
#
#                                              Variable
# 0                        Annual Production|Cane Sugar
# 1                        Annual Production|Cane Sugar
# 2                        Annual Production|Cane Sugar
# 3                              Annual Production|Beer
# 4                        Annual Production|Cane Sugar
# ...                                               ...
# 6132                   Number of Units|Crop Harvester
# 6133                      Number of Units|Televisions
# 6134         Share of Population|Tuberculosis Vaccine
# 6135  Share of Population|Measles Vaccine Second Dose
# 6136                   Number of Units|Crop Harvester
#
# [6127 rows x 9 columns]

# %% [markdown]
# #### Create dataframe of only the time series

# %%
tech_timeseries_nosum = all_tech_country.iloc[:,10:]

# %% [markdown]
# ##### Convert year column names to integers.

# %%
# Get current column name values and convert to integers 
num_colyears = [int(year) for year in tech_timeseries_nosum.columns.values.tolist()]

# Reapply the integer column names onto the df
tech_timeseries_nosum.columns = num_colyears

# %% [markdown]
# ### Data Cleaning

# %%
## Ensure that data is clean

# Define the values to replace with NaN
replace_values = {'...': np.nan, '... ': np.nan, '…': np.nan, '… ': np.nan, '··· ': np.nan, '···': np.nan, 'W': np.nan, ' ': np.nan, '-- ': np.nan, '--': np.nan}

# Replace the values with NaN
tech_timeseries_nosum = tech_timeseries_nosum.replace(replace_values)

#turn all non-nan values into float
for col in tech_timeseries_nosum.columns:
    try:
        # Convert each value to float, handling commas
        tech_timeseries_nosum[col] = tech_timeseries_nosum[col].apply(lambda x: float(str(x).replace(',', '')))
    except ValueError as e:
        print("Error converting value to float.")
        print("Error message:", e)

# Turn all non-nan values into float
tech_timeseries_nosum = tech_timeseries_nosum.astype(float)

# %% [markdown]
# #### Combine summary and time series dataframes and clean

# %%
# Create dataframe combining the cleaned time series and data description dataframes
all_tech_country_clean = pd.concat([tech_timeseries_sum, tech_timeseries_nosum], axis=1)

# %% [markdown]
# #### Fix country names
# - ensure alignment
# - switch ISO2 to ISO3 codes.

# %%
# List country names for alignment.
replacements = {
    'Phillipines': 'Philippines',
    'Phillipine': 'Philippines',
    'Kyrgistan': 'Kyrgyzstan',
    'Yugoslav SFR': 'Yugoslavia',
    'Southern Vietnam': 'South Vietnam'
}

for old_name, new_name in replacements.items():
    all_tech_country_clean['Country Name'].replace(old_name, new_name, inplace=True)

# %%
all_tech_country_clean.rename(columns={'Region': 'Country Code'}, inplace=True)


## Convert ISO2 code to ISO3 code for countries
country_names = all_tech_country_clean["Country Name"].tolist()

new_codes = countrycode(country_names, 
                        origin = "country.name", 
                        destination = "iso3c")


all_tech_country_clean['Country Code'] = countrycode(all_tech_country_clean["Country Name"].tolist(),
                                                  origin='country.name',
                                                  destination='iso3c')

# %% [markdown]
# #### Remove global values.

# %%
# Create dataframe without global values
all_tech_country_clean_noworld = all_tech_country_clean[~all_tech_country_clean['Country Name'].str.contains('World')]

# %%
all_tech_country_clean_noworld
# Out:
#                                        ID Spatial Scale Country Code  \
# 0       Sugar Output_Annual Production_JM      National          JAM
# 1       Sugar Output_Annual Production_BB      National          BRB
# 2       Sugar Output_Annual Production_CU      National          CUB
# 3               Beer_Annual Production_GB      National          GBR
# 4       Sugar Output_Annual Production_MU      National          MUS
# ...                                   ...           ...          ...
# 6132       Crop Harvester_Total Number_UZ      National          UZB
# 6133           Television_Total Number_BA      National          BIH
# 6134   BCG Vaccine_Share of Population_AT      National          AUT
# 6135  MCV2 Vaccine_Share of Population_DJ      National          DJI
# 6136       Crop Harvester_Total Number_UA      National          UKR
#
#             Country Name  Technology Name               Metric  \
# 0                Jamaica     Sugar Output    Annual Production
# 1               Barbados     Sugar Output    Annual Production
# 2                   Cuba     Sugar Output    Annual Production
# 3                     UK  Beer Production    Annual Production
# 4              Mauritius     Sugar Output    Annual Production
# ...                  ...              ...                  ...
# 6132          Uzbekistan   Crop Harvester         Total Number
# 6133  Bosnia-Herzegovina       Television         Total Number
# 6134             Austria      BCG Vaccine  Share of Population
# 6135            Djibouti     MCV2 Vaccine  Share of Population
# 6136             Ukraine   Crop Harvester         Total Number
#
#                       Unit Data Source  \
# 0     thousand metric tons    Mitchell
# 1     thousand metric tons    Mitchell
# 2     thousand metric tons    Mitchell
# 3     thousand hectolitres    Mitchell
# 4     thousand metric tons    Mitchell
# ...                    ...         ...
# 6132                     -        CHAT
# 6133                     -        CHAT
# 6134                     %      UNICEF
# 6135                     %      UNICEF
# 6136                     -        CHAT
#
#                                              Variable  1701  ...  2016  2017  \
# 0                        Annual Production|Cane Sugar   NaN  ...   NaN   NaN
# 1                        Annual Production|Cane Sugar   NaN  ...   NaN   NaN
# 2                        Annual Production|Cane Sugar   NaN  ...   NaN   NaN
# 3                              Annual Production|Beer   NaN  ...   NaN   NaN
# 4                        Annual Production|Cane Sugar   NaN  ...   NaN   NaN
# ...                                               ...   ...  ...   ...   ...
# 6132                   Number of Units|Crop Harvester   NaN  ...   NaN   NaN
# 6133                      Number of Units|Televisions   NaN  ...   NaN   NaN
# 6134         Share of Population|Tuberculosis Vaccine   NaN  ...   NaN   NaN
# 6135  Share of Population|Measles Vaccine Second Dose   NaN  ...  0.81  0.81
# 6136                   Number of Units|Crop Harvester   NaN  ...   NaN   NaN
#
#       2018  2019  2020  2021  2022  2023  2024  2025
# 0      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...    ...   ...   ...   ...   ...   ...   ...   ...
# 6132   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6133   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6134   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6135  0.81  0.81   0.6  0.48   NaN   NaN   NaN   NaN
# 6136   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [6032 rows x 334 columns]

# %% [markdown]
# #### Save files - All technologies with world data and without

# %%
save_filename = "all_tech_clean.csv"
save_path = os.path.join(save_filename)                
all_tech_country_clean_noworld.to_csv(save_path) 

save_filename = "all_tech_with_world.csv"
save_path = os.path.join(save_filename)
all_tech_country_clean.to_csv(save_path)

# %% [markdown]
# # Code block to analyze each time-country time series

# %%
def find_last_year(df, index):
    row_values = df.loc[index]
    for year, value in reversed(list(row_values.items())):
        if pd.notnull(value) and (value!=0):
            return year
    return None

# %%
#Find first year function given a dataframe and index
def find_first_year(df, index):
    row_values = df.loc[index]
    for year, value in row_values.iteritems():
        if pd.notnull(value) and (value !=0):
            return year
    return None

# %%
# In this function, input the time series and the descriptions
def annual_to_cumulative(num_df, sum_df):
    filtered_tech_timeseries_nosum_cum = num_df.copy()
    filtered_tech_timeseries_sum_cum = sum_df.copy()

    for row in filtered_tech_timeseries_nosum_cum.index:
        # Check the value in the 'metric' column
        metric_value = filtered_tech_timeseries_sum_cum.at[row, 'Metric']

        tech_value = filtered_tech_timeseries_sum_cum.at[row, 'Technology Name']

        ## For some data, the metrics should not be converted to cumulative.
        # These include those already in cumulative terms, and market share. Also annual production is a proxy for cumulative capacity
        if ('Cumulative' in metric_value or 
            'Share' in metric_value or 
            'Annual production' in metric_value or 
            'Installed electricity capacity' in metric_value or
            'Annual Production' in metric_value or
            'Average Capacity of Unit Additions' in metric_value or
            'Computing Capacity' in metric_value):
            continue

        ## as of Oct 2 2023, there is an issue with Github data. So we use the number of units and cumulative number of
        # units distinction from IIASA data, but by technology.
        
        if ('Railroad' in tech_value or
           'Oil Refining Capacity' in tech_value or
           'Oil Pipeline' in tech_value or
           'Gas Pipeline' in tech_value or
           'Public Roads' in tech_value ):
            continue

        # there are also technologies that are measured as 'number in use'
        # steamships, telephones, televisions, radios, cellphones, crop harvesters, cars
        # For now, we consider these cumulative.

        if ('Telephone' in tech_value or
           'Canals' in tech_value or
           'Cellphones' in tech_value or
           'Crop Harvester' in tech_value or
           'Home Air Conditioning' in tech_value or
           'Jet Aircraft' in tech_value or
           'Nuclear Weapons' in tech_value or
           'Radio' in tech_value or
           'Steamships' in tech_value or
           'Television' in tech_value):
            continue
        print(tech_value)


        # Update the value in the 'metric' column
        filtered_tech_timeseries_sum_cum.at[row, 'Metric'] = 'Cumulative Calculation'

        # Find last year in data time series
        last_year_tech = find_last_year(num_df, row)
        try:
            length = filtered_tech_timeseries_nosum_cum.columns.get_loc(last_year_tech)

            # Iterate over each column (year) starting from the second column
            for col in filtered_tech_timeseries_nosum_cum.columns[1:length + 1]:

                if col not in filtered_tech_timeseries_nosum_cum:
                    continue

                current_val = filtered_tech_timeseries_nosum_cum.at[row, col]
                prev_val = filtered_tech_timeseries_nosum_cum.at[row, col - 1]

                if np.isnan(current_val):
                    filtered_tech_timeseries_nosum_cum.at[row, col] = prev_val

                elif np.isnan(prev_val) and not np.isnan(current_val):
                    filtered_tech_timeseries_nosum_cum.at[row, col] = current_val
                else:
                    filtered_tech_timeseries_nosum_cum.at[row, col] = current_val + prev_val
        except Exception as e:
            print(f"Error occurred for index {row}: {e}")
            print(f"Details: {str(e)}")


    return filtered_tech_timeseries_sum_cum, filtered_tech_timeseries_nosum_cum

# %% [markdown]
# ##### Apply annual to cumulative calculation

# %%
# Apply annual to cumulative conversions to the data 

# Dataframes to convert
tech_time_series = all_tech_country_clean_noworld.iloc[:,10:]
tech_summary = all_tech_country_clean_noworld.iloc[:, 0:9]


## Apply annual to cumulative calculation
cum_tech_growth_sum, cum_tech_growth = annual_to_cumulative(tech_time_series, 
                                                            tech_summary)

# Combine two dataframes (summary and time series)
cum_tech_growth_all = pd.concat([cum_tech_growth_sum, cum_tech_growth], axis=1)

#cum_tech_growth_all
# Out:
# Telegraph Traffic
# Postal Traffic
# Telegraph Traffic
# Postal Traffic
# Postal Traffic
# Telegraph Traffic
# Telegraph Traffic
# Telegraph Traffic
# Postal Traffic
# Telegraph Traffic
# Postal Traffic
# Postal Traffic
# Postal Traffic
# Postal Traffic
# Telegraph Traffic
# Telegraph Traffic
# Telegraph Traffic
# Postal Traffic
# Postal Traffic
# Postal Traffic
# Postal Traffic
# Telegraph Traffic
# Telegraph Traffic
# Postal Traffic
# Telegraph Traffic
# Postal Traffic
# Postal Traffic
# Postal Traffic
# Telegraph Traffic
# Telegraph Traffic
# Postal Traffic
# Postal Traffic
# Telegraph Traffic
# Telegraph Traffic
# Telegraph Traffic
# Telegraph Traffic
# Telegraph Traffic
# Telegraph Traffic
# Postal Traffic
# Postal Traffic
# Telegraph Traffic
# Telegraph Traffic
# Postal Traffic
# Telegraph Traffic
# Postal Traffic
# Telegraph Traffic
# Telegraph Traffic
# Telegraph Traffic
# Postal Traffic
# Passenger Vehicles
# Telegraph Traffic
# Passenger Vehicles
# Postal Traffic
# Telegraph Traffic
# Telegraph Traffic
# Postal Traffic
# Postal Traffic
# Passenger Vehicles
# Passenger Vehicles
# Postal Traffic
# Postal Traffic
# Postal Traffic
# Postal Traffic
# Postal Traffic
# Passenger Vehicles
# Postal Traffic
# Telegraph Traffic
# Postal Traffic
# Telegraph Traffic
# Postal Traffic
# Postal Traffic
# Passenger Vehicles
# Passenger Vehicles
# Telegraph Traffic
# Passenger Vehicles
# Passenger Vehicles
# Postal Traffic
# Telegraph Traffic
# Postal Traffic
# Passenger Vehicles
# Passenger Vehicles
# Postal Traffic
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Postal Traffic
# Telegraph Traffic
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Telegraph Traffic
# Telegraph Traffic
# Postal Traffic
# Telegraph Traffic
# Passenger Vehicles
# Telegraph Traffic
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Telegraph Traffic
# Telegraph Traffic
# Passenger Vehicles
# Postal Traffic
# Postal Traffic
# Postal Traffic
# Passenger Vehicles
# Telegraph Traffic
# Telegraph Traffic
# Passenger Vehicles
# Postal Traffic
# Telegraph Traffic
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Postal Traffic
# Telegraph Traffic
# Telegraph Traffic
# Passenger Vehicles
# Objects Launched Into Space
# Passenger Vehicles
# Passenger Vehicles
# Objects Launched Into Space
# Telegraph Traffic
# Postal Traffic
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Postal Traffic
# Passenger Vehicles
# Postal Traffic
# Passenger Vehicles
# Telegraph Traffic
# Telegraph Traffic
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Postal Traffic
# Postal Traffic
# Telegraph Traffic
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Telegraph Traffic
# Passenger Vehicles
# Telegraph Traffic
# Postal Traffic
# Telegraph Traffic
# Postal Traffic
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Telegraph Traffic
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Telegraph Traffic
# Passenger Vehicles
# Telegraph Traffic
# Passenger Vehicles
# Telegraph Traffic
# Passenger Vehicles
# Objects Launched Into Space
# Postal Traffic
# Postal Traffic
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Telegraph Traffic
# Passenger Vehicles
# Postal Traffic
# Passenger Vehicles
# Postal Traffic
# Passenger Vehicles
# Telegraph Traffic
# Postal Traffic
# Postal Traffic
# Passenger Vehicles
# Telegraph Traffic
# Passenger Vehicles
# Passenger Vehicles
# Telegraph Traffic
# Telegraph Traffic
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Objects Launched Into Space
# Passenger Vehicles
# Passenger Vehicles
# Telegraph Traffic
# Passenger Vehicles
# Telegraph Traffic
# Passenger Vehicles
# Postal Traffic
# Postal Traffic
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Postal Traffic
# Telegraph Traffic
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Postal Traffic
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Telegraph Traffic
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Postal Traffic
# Postal Traffic
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Objects Launched Into Space
# Postal Traffic
# High Speed Rail
# High Speed Rail
# High Speed Rail
# High Speed Rail
# High Speed Rail
# High Speed Rail
# High Speed Rail
# High Speed Rail
# High Speed Rail
# High Speed Rail
# Objects Launched Into Space
# High Speed Rail
# High Speed Rail
# High Speed Rail
# High Speed Rail
# Passenger Vehicles
# Objects Launched Into Space
# Objects Launched Into Space
# Objects Launched Into Space
# Telegraph Traffic
# Passenger Vehicles
# Postal Traffic
# Passenger Vehicles
# Telegraph Traffic
# Telegraph Traffic
# Passenger Vehicles
# Telegraph Traffic
# Passenger Vehicles
# Passenger Vehicles
# Postal Traffic
# Postal Traffic
# Postal Traffic
# Passenger Vehicles
# Passenger Vehicles
# Postal Traffic
# Passenger Vehicles
# Postal Traffic
# Passenger Vehicles
# Postal Traffic
# Postal Traffic
# Objects Launched Into Space
# Telegraph Traffic
# Passenger Vehicles
# Telegraph Traffic
# Telegraph Traffic
# Passenger Vehicles
# Passenger Vehicles
# Postal Traffic
# Postal Traffic
# Passenger Vehicles
# Objects Launched Into Space
# Telegraph Traffic
# Objects Launched Into Space
# Passenger Vehicles
# Telegraph Traffic
# Passenger Vehicles
# Postal Traffic
# Postal Traffic
# Objects Launched Into Space
# Objects Launched Into Space
# Objects Launched Into Space
# Telegraph Traffic
# Objects Launched Into Space
# Passenger Vehicles
# Ground Source Heat Pumps
# Objects Launched Into Space
# Telegraph Traffic
# Postal Traffic
# Passenger Vehicles
# Objects Launched Into Space
# Objects Launched Into Space
# Objects Launched Into Space
# Objects Launched Into Space
# Passenger Vehicles
# Objects Launched Into Space
# Postal Traffic
# Objects Launched Into Space
# Passenger Vehicles
# Passenger Vehicles
# Objects Launched Into Space
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles
# Passenger Vehicles

# %%
cum_tech_growth_all
# Out:
#                                        ID Spatial Scale Country Code  \
# 0       Sugar Output_Annual Production_JM      National          JAM
# 1       Sugar Output_Annual Production_BB      National          BRB
# 2       Sugar Output_Annual Production_CU      National          CUB
# 3               Beer_Annual Production_GB      National          GBR
# 4       Sugar Output_Annual Production_MU      National          MUS
# ...                                   ...           ...          ...
# 6132       Crop Harvester_Total Number_UZ      National          UZB
# 6133           Television_Total Number_BA      National          BIH
# 6134   BCG Vaccine_Share of Population_AT      National          AUT
# 6135  MCV2 Vaccine_Share of Population_DJ      National          DJI
# 6136       Crop Harvester_Total Number_UA      National          UKR
#
#             Country Name  Technology Name               Metric  \
# 0                Jamaica     Sugar Output    Annual Production
# 1               Barbados     Sugar Output    Annual Production
# 2                   Cuba     Sugar Output    Annual Production
# 3                     UK  Beer Production    Annual Production
# 4              Mauritius     Sugar Output    Annual Production
# ...                  ...              ...                  ...
# 6132          Uzbekistan   Crop Harvester         Total Number
# 6133  Bosnia-Herzegovina       Television         Total Number
# 6134             Austria      BCG Vaccine  Share of Population
# 6135            Djibouti     MCV2 Vaccine  Share of Population
# 6136             Ukraine   Crop Harvester         Total Number
#
#                       Unit Data Source  \
# 0     thousand metric tons    Mitchell
# 1     thousand metric tons    Mitchell
# 2     thousand metric tons    Mitchell
# 3     thousand hectolitres    Mitchell
# 4     thousand metric tons    Mitchell
# ...                    ...         ...
# 6132                     -        CHAT
# 6133                     -        CHAT
# 6134                     %      UNICEF
# 6135                     %      UNICEF
# 6136                     -        CHAT
#
#                                              Variable  1702  ...  2016  2017  \
# 0                        Annual Production|Cane Sugar   NaN  ...   NaN   NaN
# 1                        Annual Production|Cane Sugar   NaN  ...   NaN   NaN
# 2                        Annual Production|Cane Sugar   NaN  ...   NaN   NaN
# 3                              Annual Production|Beer   NaN  ...   NaN   NaN
# 4                        Annual Production|Cane Sugar   NaN  ...   NaN   NaN
# ...                                               ...   ...  ...   ...   ...
# 6132                   Number of Units|Crop Harvester   NaN  ...   NaN   NaN
# 6133                      Number of Units|Televisions   NaN  ...   NaN   NaN
# 6134         Share of Population|Tuberculosis Vaccine   NaN  ...   NaN   NaN
# 6135  Share of Population|Measles Vaccine Second Dose   NaN  ...  0.81  0.81
# 6136                   Number of Units|Crop Harvester   NaN  ...   NaN   NaN
#
#       2018  2019  2020  2021  2022  2023  2024  2025
# 0      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...    ...   ...   ...   ...   ...   ...   ...   ...
# 6132   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6133   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6134   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6135  0.81  0.81   0.6  0.48   NaN   NaN   NaN   NaN
# 6136   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [6032 rows x 333 columns]

# %% [markdown]
# ### Save CSV

# %%
cum_tech_growth_all

save_filename = "all_tech_clean_cumulative_Updated.csv"
save_path = os.path.join(save_filename)                
cum_tech_growth_all.to_csv(save_path)
